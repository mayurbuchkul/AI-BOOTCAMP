# %%
# !pip install wordcloud

# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ICEEM\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ICEEM\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Provided text
text = """
Artificial Intelligence (AI) is revolutionizing the way we interact with technology.
By simulating human intelligence, AI systems can learn, reason, and make decisions.
From voice assistants like Siri to self-driving cars, AI is becoming a part of everyday life.
It holds the potential to solve complex problems in fields such as healthcare, finance, and education.
As AI continues to evolve, it promises to unlock new possibilities, making tasks more efficient and transforming industries across the globe
"""
print(text)
# Out:
# Artificial Intelligence (AI) is revolutionizing the way we interact with technology.
# By simulating human intelligence, AI systems can learn, reason, and make decisions.
# From voice assistants like Siri to self-driving cars, AI is becoming a part of everyday life.
# It holds the potential to solve complex problems in fields such as healthcare, finance, and education.
# As AI continues to evolve, it promises to unlock new possibilities, making tasks more efficient and transforming industries across the globe

# %%
# Tokenization of words
words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)
# Out:
# ['artificial', 'intelligence', '(', 'ai', ')', 'is', 'revolutionizing', 'the', 'way', 'we', 'interact', 'with', 'technology', '.', 'by', 'simulating', 'human', 'intelligence', ',', 'ai', 'systems', 'can', 'learn', ',', 'reason', ',', 'and', 'make', 'decisions', '.', 'from', 'voice', 'assistants', 'like', 'siri', 'to', 'self-driving', 'cars', ',', 'ai', 'is', 'becoming', 'a', 'part', 'of', 'everyday', 'life', '.', 'it', 'holds', 'the', 'potential', 'to', 'solve', 'complex', 'problems', 'in', 'fields', 'such', 'as', 'healthcare', ',', 'finance', ',', 'and', 'education', '.', 'as', 'ai', 'continues', 'to', 'evolve', ',', 'it', 'promises', 'to', 'unlock', 'new', 'possibilities', ',', 'making', 'tasks', 'more', 'efficient', 'and', 'transforming', 'industries', 'across', 'the', 'globe']

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)
# Out:
# ['artificial', 'intelligence', 'ai', 'revolutionizing', 'way', 'interact', 'technology', 'simulating', 'human', 'intelligence', 'ai', 'systems', 'learn', 'reason', 'make', 'decisions', 'voice', 'assistants', 'like', 'siri', 'cars', 'ai', 'becoming', 'part', 'everyday', 'life', 'holds', 'potential', 'solve', 'complex', 'problems', 'fields', 'healthcare', 'finance', 'education', 'ai', 'continues', 'evolve', 'promises', 'unlock', 'new', 'possibilities', 'making', 'tasks', 'efficient', 'transforming', 'industries', 'across', 'globe']

# %%
# Frequency distribution of words
word_freq = Counter(filtered_words)
print(word_freq)
# Out:
# Counter({'ai': 4, 'intelligence': 2, 'artificial': 1, 'revolutionizing': 1, 'way': 1, 'interact': 1, 'technology': 1, 'simulating': 1, 'human': 1, 'systems': 1, 'learn': 1, 'reason': 1, 'make': 1, 'decisions': 1, 'voice': 1, 'assistants': 1, 'like': 1, 'siri': 1, 'cars': 1, 'becoming': 1, 'part': 1, 'everyday': 1, 'life': 1, 'holds': 1, 'potential': 1, 'solve': 1, 'complex': 1, 'problems': 1, 'fields': 1, 'healthcare': 1, 'finance': 1, 'education': 1, 'continues': 1, 'evolve': 1, 'promises': 1, 'unlock': 1, 'new': 1, 'possibilities': 1, 'making': 1, 'tasks': 1, 'efficient': 1, 'transforming': 1, 'industries': 1, 'across': 1, 'globe': 1})

# %%
# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
# Plotting the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
